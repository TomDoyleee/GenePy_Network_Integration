# %% [markdown]
# # String API
# ---
# get String identifiers
# >Faster

# %%
import os

os.chdir('/Users/tomdoyle/')

# %%
import requests ## python -m pip install requests

string_api_url = "https://version-11-5.string-db.org/api"
output_format = "tsv-no-header"
method = "get_string_ids"

# import gene names
gene_list =[]
gene_list_file = "Documents/University/Southampton/Course/BIOL6068-Research_Project/Data/58_gene_names.txt" #gene names list
gene_list = open(gene_list_file).read().splitlines()

# human NCBI identifier 9606
species_id = 9606

## Set parameters
params = {

    "identifiers" : "\r".join(gene_list), # your protein list
    "species" : species_id, # species NCBI identifier 
    "limit" : 1, # only one (best) identifier per input protein
    "echo_query" : 1, # see your input identifiers in the output
    "caller_identity" : "Research_Project" # your app name
}

## Construct URL
request_url = "/".join([string_api_url, output_format, method])

## Call STRING
results = requests.post(request_url, data=params)

## Read and parse the results
for line in results.text.strip().split("\n"):
    l = line.split("\t")
    input_identifier, string_identifier = l[0], l[2]
    print("Input:", input_identifier, "STRING:", string_identifier, sep="\t")

# saves string_id into a list
string_id = []
for line in results.text.strip().split("\n"):
    l = line.split("\t")
    string_identifier = l[2]
    string_id.append(string_identifier)
string_id
# Out:
# Input:	BIRC2	STRING:	9606.ENSP00000477613
# Input:	BIRC3	STRING:	9606.ENSP00000263464
# Input:	CARD18	STRING:	9606.ENSP00000436691
# Input:	CARD6	STRING:	9606.ENSP00000254691
# Input:	CARD8	STRING:	9606.ENSP00000375767
# Input:	CARD9	STRING:	9606.ENSP00000360797
# Input:	CASP1	STRING:	9606.ENSP00000433138
# Input:	CASP5	STRING:	9606.ENSP00000376849
# Input:	CASP8	STRING:	9606.ENSP00000351273
# Input:	CCL11	STRING:	9606.ENSP00000302234
# Input:	CCL13	STRING:	9606.ENSP00000225844
# Input:	CCL2	STRING:	9606.ENSP00000225831
# Input:	CCL7	STRING:	9606.ENSP00000367832
# Input:	CCL8	STRING:	9606.ENSP00000378118
# Input:	CHUK	STRING:	9606.ENSP00000359424
# Input:	CXCL1	STRING:	9606.ENSP00000379110
# Input:	CXCL2	STRING:	9606.ENSP00000427279
# Input:	CXCL8	STRING:	9606.ENSP00000306512
# Input:	ERBIN	STRING:	9606.ENSP00000426632
# Input:	HSP90AA1	STRING:	9606.ENSP00000335153
# Input:	HSP90AB1	STRING:	9606.ENSP00000360609
# Input:	HSP90B1	STRING:	9606.ENSP00000299767
# Input:	IKBKB	STRING:	9606.ENSP00000430684
# Input:	IL18	STRING:	9606.ENSP00000280357
# Input:	IL1B	STRING:	9606.ENSP00000263341
# Input:	IL6	STRING:	9606.ENSP00000385675
# Input:	MAP3K7	STRING:	9606.ENSP00000358335
# Input:	MAPK1	STRING:	9606.ENSP00000215832
# Input:	MAPK10	STRING:	9606.ENSP00000352157
# Input:	MAPK11	STRING:	9606.ENSP00000333685
# Input:	MAPK12	STRING:	9606.ENSP00000215659
# Input:	MAPK13	STRING:	9606.ENSP00000211287
# Input:	MAPK14	STRING:	9606.ENSP00000229795
# Input:	MAPK3	STRING:	9606.ENSP00000263025
# Input:	MAPK8	STRING:	9606.ENSP00000378974
# Input:	MAPK9	STRING:	9606.ENSP00000394560
# Input:	MEFV	STRING:	9606.ENSP00000219596
# Input:	NFKB1	STRING:	9606.ENSP00000226574
# Input:	NFKBIA	STRING:	9606.ENSP00000216797
# Input:	NFKBIB	STRING:	9606.ENSP00000312988
# Input:	NLRC4	STRING:	9606.ENSP00000385090
# Input:	NLRP1	STRING:	9606.ENSP00000478516
# Input:	NLRP3	STRING:	9606.ENSP00000337383
# Input:	NOD1	STRING:	9606.ENSP00000222823
# Input:	NOD2	STRING:	9606.ENSP00000300589
# Input:	PSTPIP1	STRING:	9606.ENSP00000452746
# Input:	PYCARD	STRING:	9606.ENSP00000247470
# Input:	PYDC1	STRING:	9606.ENSP00000304336
# Input:	RELA	STRING:	9606.ENSP00000384273
# Input:	RIPK2	STRING:	9606.ENSP00000220751
# Input:	SUGT1	STRING:	9606.ENSP00000367208
# Input:	TAB1	STRING:	9606.ENSP00000216160
# Input:	TAB2	STRING:	9606.ENSP00000356426
# Input:	TAB3	STRING:	9606.ENSP00000368215
# Input:	TNFAIP3	STRING:	9606.ENSP00000481570
# Input:	TRAF6	STRING:	9606.ENSP00000433623
# Input:	TRIP6	STRING:	9606.ENSP00000200457
# Input:	XIAP	STRING:	9606.ENSP00000360242
# ['9606.ENSP00000477613',
#  '9606.ENSP00000263464',
#  '9606.ENSP00000436691',
#  '9606.ENSP00000254691',
#  '9606.ENSP00000375767',
#  '9606.ENSP00000360797',
#  '9606.ENSP00000433138',
#  '9606.ENSP00000376849',
#  '9606.ENSP00000351273',
#  '9606.ENSP00000302234',
#  '9606.ENSP00000225844',
#  '9606.ENSP00000225831',
#  '9606.ENSP00000367832',
#  '9606.ENSP00000378118',
#  '9606.ENSP00000359424',
#  '9606.ENSP00000379110',
#  '9606.ENSP00000427279',
#  '9606.ENSP00000306512',
#  '9606.ENSP00000426632',
#  '9606.ENSP00000335153',
#  '9606.ENSP00000360609',
#  '9606.ENSP00000299767',
#  '9606.ENSP00000430684',
#  '9606.ENSP00000280357',
#  '9606.ENSP00000263341',
#  '9606.ENSP00000385675',
#  '9606.ENSP00000358335',
#  '9606.ENSP00000215832',
#  '9606.ENSP00000352157',
#  '9606.ENSP00000333685',
#  '9606.ENSP00000215659',
#  '9606.ENSP00000211287',
#  '9606.ENSP00000229795',
#  '9606.ENSP00000263025',
#  '9606.ENSP00000378974',
#  '9606.ENSP00000394560',
#  '9606.ENSP00000219596',
#  '9606.ENSP00000226574',
#  '9606.ENSP00000216797',
#  '9606.ENSP00000312988',
#  '9606.ENSP00000385090',
#  '9606.ENSP00000478516',
#  '9606.ENSP00000337383',
#  '9606.ENSP00000222823',
#  '9606.ENSP00000300589',
#  '9606.ENSP00000452746',
#  '9606.ENSP00000247470',
#  '9606.ENSP00000304336',
#  '9606.ENSP00000384273',
#  '9606.ENSP00000220751',
#  '9606.ENSP00000367208',
#  '9606.ENSP00000216160',
#  '9606.ENSP00000356426',
#  '9606.ENSP00000368215',
#  '9606.ENSP00000481570',
#  '9606.ENSP00000433623',
#  '9606.ENSP00000200457',
#  '9606.ENSP00000360242']

# %% [markdown]
# # Get network interactions
#
# ## retieve experimental scores over 0.6

# %%
output_format = "tsv-no-header"
method = "network"

## Construct URL
request_url = "/".join([string_api_url, output_format, method])

# set confience_score between 0-1
confidence_score = 0.6

## Set parameters
my_genes = string_id

params = {

    "identifiers" : "%0d".join(my_genes), # your protein
    "species" : species_id, # species NCBI identifier 
    "caller_identity" : "Research_Project" # your app name
    

}

""" other params
"required_score" :	# threshold of significance to include a interaction, a number between 0 and 1000 (default depends on the network)
    "network_type" :	# network type: functional (default), physical
    "add_nodes"	: # adds a number of proteins with to the network based on their confidence score
    "show_query_node_labels" :	# when available use submitted names in the preferredName column when (0 or 1) (default:0)
    """

## Call STRING
response = requests.post(request_url, data=params)

for line in response.text.strip().split("\n"):

    l = line.strip().split("\t")
    p1, p2 = l[2], l[3]

    ## filter the interaction according to experimental score
    experimental_score = float(l[10])
    if experimental_score > confidence_score:
        print("\t".join([p1, p2, "experimentally confirmed (prob. %.3f)" % experimental_score]))
# Out:
# MAPK1	MAPK14	experimentally confirmed (prob. 0.874)
# MAPK1	MAPK14	experimentally confirmed (prob. 0.874)
# MAPK1	MAPK3	experimentally confirmed (prob. 0.887)
# MAPK1	MAPK3	experimentally confirmed (prob. 0.887)
# TAB1	MAPK11	experimentally confirmed (prob. 0.684)
# TAB1	MAPK11	experimentally confirmed (prob. 0.684)
# TAB1	TAB3	experimentally confirmed (prob. 0.863)
# TAB1	TAB3	experimentally confirmed (prob. 0.863)
# TAB1	TRAF6	experimentally confirmed (prob. 0.760)
# TAB1	TRAF6	experimentally confirmed (prob. 0.760)
# TAB1	MAP3K7	experimentally confirmed (prob. 0.980)
# TAB1	MAP3K7	experimentally confirmed (prob. 0.980)
# TAB1	MAPK14	experimentally confirmed (prob. 0.966)
# TAB1	MAPK14	experimentally confirmed (prob. 0.966)
# TAB1	TAB2	experimentally confirmed (prob. 0.897)
# TAB1	TAB2	experimentally confirmed (prob. 0.897)
# TAB1	XIAP	experimentally confirmed (prob. 0.879)
# TAB1	XIAP	experimentally confirmed (prob. 0.879)
# NFKBIA	NFKBIB	experimentally confirmed (prob. 0.877)
# NFKBIA	NFKBIB	experimentally confirmed (prob. 0.877)
# NFKBIA	IKBKB	experimentally confirmed (prob. 0.996)
# NFKBIA	IKBKB	experimentally confirmed (prob. 0.996)
# NFKBIA	RELA	experimentally confirmed (prob. 0.998)
# NFKBIA	RELA	experimentally confirmed (prob. 0.998)
# NFKBIA	NFKB1	experimentally confirmed (prob. 0.986)
# NFKBIA	NFKB1	experimentally confirmed (prob. 0.986)
# NFKBIA	CHUK	experimentally confirmed (prob. 0.994)
# NFKBIA	CHUK	experimentally confirmed (prob. 0.994)
# MEFV	PYCARD	experimentally confirmed (prob. 0.865)
# MEFV	PYCARD	experimentally confirmed (prob. 0.865)
# MEFV	PSTPIP1	experimentally confirmed (prob. 0.678)
# MEFV	PSTPIP1	experimentally confirmed (prob. 0.678)
# RIPK2	MAP3K7	experimentally confirmed (prob. 0.835)
# RIPK2	MAP3K7	experimentally confirmed (prob. 0.835)
# RIPK2	BIRC3	experimentally confirmed (prob. 0.700)
# RIPK2	BIRC3	experimentally confirmed (prob. 0.700)
# RIPK2	TRAF6	experimentally confirmed (prob. 0.694)
# RIPK2	TRAF6	experimentally confirmed (prob. 0.694)
# RIPK2	BIRC2	experimentally confirmed (prob. 0.772)
# RIPK2	BIRC2	experimentally confirmed (prob. 0.772)
# RIPK2	NOD2	experimentally confirmed (prob. 0.879)
# RIPK2	NOD2	experimentally confirmed (prob. 0.879)
# RIPK2	XIAP	experimentally confirmed (prob. 0.880)
# RIPK2	XIAP	experimentally confirmed (prob. 0.880)
# RIPK2	NOD1	experimentally confirmed (prob. 0.871)
# RIPK2	NOD1	experimentally confirmed (prob. 0.871)
# NOD1	SUGT1	experimentally confirmed (prob. 0.675)
# NOD1	SUGT1	experimentally confirmed (prob. 0.675)
# NOD1	HSP90AA1	experimentally confirmed (prob. 0.748)
# NOD1	HSP90AA1	experimentally confirmed (prob. 0.748)
# NFKB1	NFKBIB	experimentally confirmed (prob. 0.878)
# NFKB1	NFKBIB	experimentally confirmed (prob. 0.878)
# NFKB1	CHUK	experimentally confirmed (prob. 0.965)
# NFKB1	CHUK	experimentally confirmed (prob. 0.965)
# NFKB1	RELA	experimentally confirmed (prob. 0.998)
# NFKB1	RELA	experimentally confirmed (prob. 0.998)
# NFKB1	IKBKB	experimentally confirmed (prob. 0.963)
# NFKB1	IKBKB	experimentally confirmed (prob. 0.963)
# MAPK14	MAPK3	experimentally confirmed (prob. 0.777)
# MAPK14	MAPK3	experimentally confirmed (prob. 0.777)
# PYCARD	CASP8	experimentally confirmed (prob. 0.710)
# PYCARD	CASP8	experimentally confirmed (prob. 0.710)
# PYCARD	NLRP3	experimentally confirmed (prob. 0.884)
# PYCARD	NLRP3	experimentally confirmed (prob. 0.884)
# PYCARD	CASP1	experimentally confirmed (prob. 0.977)
# PYCARD	CASP1	experimentally confirmed (prob. 0.977)
# IL1B	CASP1	experimentally confirmed (prob. 0.773)
# IL1B	CASP1	experimentally confirmed (prob. 0.773)
# BIRC3	RELA	experimentally confirmed (prob. 0.675)
# BIRC3	RELA	experimentally confirmed (prob. 0.675)
# BIRC3	TRAF6	experimentally confirmed (prob. 0.841)
# BIRC3	TRAF6	experimentally confirmed (prob. 0.841)
# HSP90B1	BIRC2	experimentally confirmed (prob. 0.621)
# HSP90B1	BIRC2	experimentally confirmed (prob. 0.621)
# HSP90B1	SUGT1	experimentally confirmed (prob. 0.813)
# HSP90B1	SUGT1	experimentally confirmed (prob. 0.813)
# NOD2	XIAP	experimentally confirmed (prob. 0.675)
# NOD2	XIAP	experimentally confirmed (prob. 0.675)
# NOD2	MAP3K7	experimentally confirmed (prob. 0.675)
# NOD2	MAP3K7	experimentally confirmed (prob. 0.675)
# CXCL8	RELA	experimentally confirmed (prob. 0.753)
# CXCL8	RELA	experimentally confirmed (prob. 0.753)
# NFKBIB	IKBKB	experimentally confirmed (prob. 0.770)
# NFKBIB	IKBKB	experimentally confirmed (prob. 0.770)
# NFKBIB	CHUK	experimentally confirmed (prob. 0.830)
# NFKBIB	CHUK	experimentally confirmed (prob. 0.830)
# NFKBIB	RELA	experimentally confirmed (prob. 0.895)
# NFKBIB	RELA	experimentally confirmed (prob. 0.895)
# HSP90AA1	HSP90AB1	experimentally confirmed (prob. 0.888)
# HSP90AA1	HSP90AB1	experimentally confirmed (prob. 0.888)
# HSP90AA1	IKBKB	experimentally confirmed (prob. 0.723)
# HSP90AA1	IKBKB	experimentally confirmed (prob. 0.723)
# HSP90AA1	CHUK	experimentally confirmed (prob. 0.774)
# HSP90AA1	CHUK	experimentally confirmed (prob. 0.774)
# HSP90AA1	SUGT1	experimentally confirmed (prob. 0.992)
# HSP90AA1	SUGT1	experimentally confirmed (prob. 0.992)
# CASP8	TNFAIP3	experimentally confirmed (prob. 0.680)
# CASP8	TNFAIP3	experimentally confirmed (prob. 0.680)
# CASP8	NLRC4	experimentally confirmed (prob. 0.683)
# CASP8	NLRC4	experimentally confirmed (prob. 0.683)
# CASP8	XIAP	experimentally confirmed (prob. 0.729)
# CASP8	XIAP	experimentally confirmed (prob. 0.729)
# CASP8	TRAF6	experimentally confirmed (prob. 0.816)
# CASP8	TRAF6	experimentally confirmed (prob. 0.816)
# CASP8	BIRC2	experimentally confirmed (prob. 0.861)
# CASP8	BIRC2	experimentally confirmed (prob. 0.861)
# TAB2	TAB3	experimentally confirmed (prob. 0.608)
# TAB2	TAB3	experimentally confirmed (prob. 0.608)
# TAB2	MAP3K7	experimentally confirmed (prob. 0.994)
# TAB2	MAP3K7	experimentally confirmed (prob. 0.994)
# TAB2	TRAF6	experimentally confirmed (prob. 0.920)
# TAB2	TRAF6	experimentally confirmed (prob. 0.920)
# MAP3K7	RELA	experimentally confirmed (prob. 0.685)
# MAP3K7	RELA	experimentally confirmed (prob. 0.685)
# MAP3K7	MAPK8	experimentally confirmed (prob. 0.661)
# MAP3K7	MAPK8	experimentally confirmed (prob. 0.661)
# MAP3K7	XIAP	experimentally confirmed (prob. 0.700)
# MAP3K7	XIAP	experimentally confirmed (prob. 0.700)
# MAP3K7	CHUK	experimentally confirmed (prob. 0.873)
# MAP3K7	CHUK	experimentally confirmed (prob. 0.873)
# MAP3K7	IKBKB	experimentally confirmed (prob. 0.897)
# MAP3K7	IKBKB	experimentally confirmed (prob. 0.897)
# MAP3K7	TAB3	experimentally confirmed (prob. 0.908)
# MAP3K7	TAB3	experimentally confirmed (prob. 0.908)
# MAP3K7	TRAF6	experimentally confirmed (prob. 0.994)
# MAP3K7	TRAF6	experimentally confirmed (prob. 0.994)
# CHUK	IKBKB	experimentally confirmed (prob. 0.922)
# CHUK	IKBKB	experimentally confirmed (prob. 0.922)
# CHUK	RELA	experimentally confirmed (prob. 0.878)
# CHUK	RELA	experimentally confirmed (prob. 0.878)
# XIAP	TRAF6	experimentally confirmed (prob. 0.711)
# XIAP	TRAF6	experimentally confirmed (prob. 0.711)
# XIAP	BIRC2	experimentally confirmed (prob. 0.879)
# XIAP	BIRC2	experimentally confirmed (prob. 0.879)
# HSP90AB1	IKBKB	experimentally confirmed (prob. 0.656)
# HSP90AB1	IKBKB	experimentally confirmed (prob. 0.656)
# HSP90AB1	SUGT1	experimentally confirmed (prob. 0.968)
# HSP90AB1	SUGT1	experimentally confirmed (prob. 0.968)
# TAB3	TRAF6	experimentally confirmed (prob. 0.776)
# TAB3	TRAF6	experimentally confirmed (prob. 0.776)
# MAPK8	MAPK9	experimentally confirmed (prob. 0.805)
# MAPK8	MAPK9	experimentally confirmed (prob. 0.805)
# RELA	IKBKB	experimentally confirmed (prob. 0.881)
# RELA	IKBKB	experimentally confirmed (prob. 0.881)
# NLRC4	CASP1	experimentally confirmed (prob. 0.785)
# NLRC4	CASP1	experimentally confirmed (prob. 0.785)
# IKBKB	TNFAIP3	experimentally confirmed (prob. 0.696)
# IKBKB	TNFAIP3	experimentally confirmed (prob. 0.696)
# IKBKB	TRAF6	experimentally confirmed (prob. 0.689)
# IKBKB	TRAF6	experimentally confirmed (prob. 0.689)
# CASP1	CARD18	experimentally confirmed (prob. 0.747)
# CASP1	CARD18	experimentally confirmed (prob. 0.747)
# TRAF6	TNFAIP3	experimentally confirmed (prob. 0.895)
# TRAF6	TNFAIP3	experimentally confirmed (prob. 0.895)

# %% [markdown]
# ## Get combined score. confidence >0.6

# %%
for line in response.text.strip().split("\n"):

    l = line.strip().split("\t")
    p1, p2 = l[2], l[3]

    ## filter the interaction according to experimental score
    combined_score = float(l[5])
    if combined_score > confidence_score:
        print("\t".join([p1, p2, "combined score (prob. %.3f)" % combined_score]))
# Out:
# TRIP6	RIPK2	combined score (prob. 0.840)
# TRIP6	RIPK2	combined score (prob. 0.840)
# MAPK13	MAPK10	combined score (prob. 0.639)
# MAPK13	MAPK10	combined score (prob. 0.639)
# MAPK13	MAPK9	combined score (prob. 0.640)
# MAPK13	MAPK9	combined score (prob. 0.640)
# MAPK13	MAPK8	combined score (prob. 0.640)
# MAPK13	MAPK8	combined score (prob. 0.640)
# MAPK13	CARD9	combined score (prob. 0.650)
# MAPK13	CARD9	combined score (prob. 0.650)
# MAPK13	TAB3	combined score (prob. 0.682)
# MAPK13	TAB3	combined score (prob. 0.682)
# MAPK13	NOD2	combined score (prob. 0.684)
# MAPK13	NOD2	combined score (prob. 0.684)
# MAPK13	TAB2	combined score (prob. 0.686)
# MAPK13	TAB2	combined score (prob. 0.686)
# MAPK13	NOD1	combined score (prob. 0.687)
# MAPK13	NOD1	combined score (prob. 0.687)
# MAPK13	RIPK2	combined score (prob. 0.745)
# MAPK13	RIPK2	combined score (prob. 0.745)
# MAPK13	TAB1	combined score (prob. 0.803)
# MAPK13	TAB1	combined score (prob. 0.803)
# MAPK13	MAPK3	combined score (prob. 0.816)
# MAPK13	MAPK3	combined score (prob. 0.816)
# MAPK13	MAPK1	combined score (prob. 0.817)
# MAPK13	MAPK1	combined score (prob. 0.817)
# MAPK13	MAP3K7	combined score (prob. 0.842)
# MAPK13	MAP3K7	combined score (prob. 0.842)
# MAPK13	MAPK14	combined score (prob. 0.906)
# MAPK13	MAPK14	combined score (prob. 0.906)
# MAPK13	MAPK11	combined score (prob. 0.907)
# MAPK13	MAPK11	combined score (prob. 0.907)
# MAPK13	MAPK12	combined score (prob. 0.942)
# MAPK13	MAPK12	combined score (prob. 0.942)
# MAPK12	MAPK9	combined score (prob. 0.645)
# MAPK12	MAPK9	combined score (prob. 0.645)
# MAPK12	MAPK8	combined score (prob. 0.646)
# MAPK12	MAPK8	combined score (prob. 0.646)
# MAPK12	MAPK10	combined score (prob. 0.646)
# MAPK12	MAPK10	combined score (prob. 0.646)
# MAPK12	CARD9	combined score (prob. 0.650)
# MAPK12	CARD9	combined score (prob. 0.650)
# MAPK12	NOD2	combined score (prob. 0.666)
# MAPK12	NOD2	combined score (prob. 0.666)
# MAPK12	TAB3	combined score (prob. 0.697)
# MAPK12	TAB3	combined score (prob. 0.697)
# MAPK12	NOD1	combined score (prob. 0.697)
# MAPK12	NOD1	combined score (prob. 0.697)
# MAPK12	TAB2	combined score (prob. 0.701)
# MAPK12	TAB2	combined score (prob. 0.701)
# MAPK12	RIPK2	combined score (prob. 0.740)
# MAPK12	RIPK2	combined score (prob. 0.740)
# MAPK12	MAPK3	combined score (prob. 0.821)
# MAPK12	MAPK3	combined score (prob. 0.821)
# MAPK12	MAP3K7	combined score (prob. 0.847)
# MAPK12	MAP3K7	combined score (prob. 0.847)
# MAPK12	TAB1	combined score (prob. 0.864)
# MAPK12	TAB1	combined score (prob. 0.864)
# MAPK12	MAPK1	combined score (prob. 0.868)
# MAPK12	MAPK1	combined score (prob. 0.868)
# MAPK12	MAPK14	combined score (prob. 0.909)
# MAPK12	MAPK14	combined score (prob. 0.909)
# MAPK12	MAPK11	combined score (prob. 0.912)
# MAPK12	MAPK11	combined score (prob. 0.912)
# MAPK1	CARD9	combined score (prob. 0.808)
# MAPK1	CARD9	combined score (prob. 0.808)
# MAPK1	MAPK11	combined score (prob. 0.816)
# MAPK1	MAPK11	combined score (prob. 0.816)
# MAPK1	MAP3K7	combined score (prob. 0.849)
# MAPK1	MAP3K7	combined score (prob. 0.849)
# MAPK1	CCL11	combined score (prob. 0.906)
# MAPK1	CCL11	combined score (prob. 0.906)
# MAPK1	MAPK8	combined score (prob. 0.931)
# MAPK1	MAPK8	combined score (prob. 0.931)
# MAPK1	HSP90AB1	combined score (prob. 0.942)
# MAPK1	HSP90AB1	combined score (prob. 0.942)
# MAPK1	RELA	combined score (prob. 0.944)
# MAPK1	RELA	combined score (prob. 0.944)
# MAPK1	NFKB1	combined score (prob. 0.945)
# MAPK1	NFKB1	combined score (prob. 0.945)
# MAPK1	NFKBIA	combined score (prob. 0.949)
# MAPK1	NFKBIA	combined score (prob. 0.949)
# MAPK1	IL6	combined score (prob. 0.957)
# MAPK1	IL6	combined score (prob. 0.957)
# MAPK1	CASP8	combined score (prob. 0.963)
# MAPK1	CASP8	combined score (prob. 0.963)
# MAPK1	MAPK14	combined score (prob. 0.977)
# MAPK1	MAPK14	combined score (prob. 0.977)
# MAPK1	HSP90AA1	combined score (prob. 0.980)
# MAPK1	HSP90AA1	combined score (prob. 0.980)
# MAPK1	MAPK3	combined score (prob. 0.988)
# MAPK1	MAPK3	combined score (prob. 0.988)
# TAB1	HSP90AA1	combined score (prob. 0.690)
# TAB1	HSP90AA1	combined score (prob. 0.690)
# TAB1	NOD2	combined score (prob. 0.745)
# TAB1	NOD2	combined score (prob. 0.745)
# TAB1	NOD1	combined score (prob. 0.777)
# TAB1	NOD1	combined score (prob. 0.777)
# TAB1	NFKB1	combined score (prob. 0.779)
# TAB1	NFKB1	combined score (prob. 0.779)
# TAB1	BIRC3	combined score (prob. 0.806)
# TAB1	BIRC3	combined score (prob. 0.806)
# TAB1	RELA	combined score (prob. 0.812)
# TAB1	RELA	combined score (prob. 0.812)
# TAB1	BIRC2	combined score (prob. 0.851)
# TAB1	BIRC2	combined score (prob. 0.851)
# TAB1	NFKBIA	combined score (prob. 0.889)
# TAB1	NFKBIA	combined score (prob. 0.889)
# TAB1	RIPK2	combined score (prob. 0.921)
# TAB1	RIPK2	combined score (prob. 0.921)
# TAB1	TNFAIP3	combined score (prob. 0.921)
# TAB1	TNFAIP3	combined score (prob. 0.921)
# TAB1	CHUK	combined score (prob. 0.970)
# TAB1	CHUK	combined score (prob. 0.970)
# TAB1	MAPK11	combined score (prob. 0.985)
# TAB1	MAPK11	combined score (prob. 0.985)
# TAB1	IKBKB	combined score (prob. 0.987)
# TAB1	IKBKB	combined score (prob. 0.987)
# TAB1	TAB3	combined score (prob. 0.997)
# TAB1	TAB3	combined score (prob. 0.997)
# TAB1	TRAF6	combined score (prob. 0.999)
# TAB1	TRAF6	combined score (prob. 0.999)
# TAB1	MAP3K7	combined score (prob. 0.999)
# TAB1	MAP3K7	combined score (prob. 0.999)
# TAB1	MAPK14	combined score (prob. 0.999)
# TAB1	MAPK14	combined score (prob. 0.999)
# TAB1	TAB2	combined score (prob. 0.999)
# TAB1	TAB2	combined score (prob. 0.999)
# TAB1	XIAP	combined score (prob. 0.999)
# TAB1	XIAP	combined score (prob. 0.999)
# NFKBIA	CASP1	combined score (prob. 0.672)
# NFKBIA	CASP1	combined score (prob. 0.672)
# NFKBIA	XIAP	combined score (prob. 0.681)
# NFKBIA	XIAP	combined score (prob. 0.681)
# NFKBIA	CXCL2	combined score (prob. 0.684)
# NFKBIA	CXCL2	combined score (prob. 0.684)
# NFKBIA	CXCL1	combined score (prob. 0.688)
# NFKBIA	CXCL1	combined score (prob. 0.688)
# NFKBIA	CCL2	combined score (prob. 0.709)
# NFKBIA	CCL2	combined score (prob. 0.709)
# NFKBIA	MAPK8	combined score (prob. 0.726)
# NFKBIA	MAPK8	combined score (prob. 0.726)
# NFKBIA	MEFV	combined score (prob. 0.734)
# NFKBIA	MEFV	combined score (prob. 0.734)
# NFKBIA	CASP8	combined score (prob. 0.756)
# NFKBIA	CASP8	combined score (prob. 0.756)
# NFKBIA	BIRC3	combined score (prob. 0.763)
# NFKBIA	BIRC3	combined score (prob. 0.763)
# NFKBIA	BIRC2	combined score (prob. 0.772)
# NFKBIA	BIRC2	combined score (prob. 0.772)
# NFKBIA	TAB3	combined score (prob. 0.820)
# NFKBIA	TAB3	combined score (prob. 0.820)
# NFKBIA	CXCL8	combined score (prob. 0.843)
# NFKBIA	CXCL8	combined score (prob. 0.843)
# NFKBIA	TAB2	combined score (prob. 0.871)
# NFKBIA	TAB2	combined score (prob. 0.871)
# NFKBIA	IL6	combined score (prob. 0.872)
# NFKBIA	IL6	combined score (prob. 0.872)
# NFKBIA	IL1B	combined score (prob. 0.882)
# NFKBIA	IL1B	combined score (prob. 0.882)
# NFKBIA	MAP3K7	combined score (prob. 0.907)
# NFKBIA	MAP3K7	combined score (prob. 0.907)
# NFKBIA	TNFAIP3	combined score (prob. 0.935)
# NFKBIA	TNFAIP3	combined score (prob. 0.935)
# NFKBIA	MAPK3	combined score (prob. 0.972)
# NFKBIA	MAPK3	combined score (prob. 0.972)
# NFKBIA	MAPK14	combined score (prob. 0.979)
# NFKBIA	MAPK14	combined score (prob. 0.979)
# NFKBIA	NFKBIB	combined score (prob. 0.983)
# NFKBIA	NFKBIB	combined score (prob. 0.983)
# NFKBIA	TRAF6	combined score (prob. 0.985)
# NFKBIA	TRAF6	combined score (prob. 0.985)
# NFKBIA	IKBKB	combined score (prob. 0.999)
# NFKBIA	IKBKB	combined score (prob. 0.999)
# NFKBIA	RELA	combined score (prob. 0.999)
# NFKBIA	RELA	combined score (prob. 0.999)
# NFKBIA	NFKB1	combined score (prob. 0.999)
# NFKBIA	NFKB1	combined score (prob. 0.999)
# NFKBIA	CHUK	combined score (prob. 0.999)
# NFKBIA	CHUK	combined score (prob. 0.999)
# MEFV	NLRP3	combined score (prob. 0.638)
# MEFV	NLRP3	combined score (prob. 0.638)
# MEFV	CARD8	combined score (prob. 0.662)
# MEFV	CARD8	combined score (prob. 0.662)
# MEFV	NOD1	combined score (prob. 0.692)
# MEFV	NOD1	combined score (prob. 0.692)
# MEFV	CASP5	combined score (prob. 0.718)
# MEFV	CASP5	combined score (prob. 0.718)
# MEFV	NOD2	combined score (prob. 0.782)
# MEFV	NOD2	combined score (prob. 0.782)
# MEFV	CASP8	combined score (prob. 0.785)
# MEFV	CASP8	combined score (prob. 0.785)
# MEFV	IL18	combined score (prob. 0.831)
# MEFV	IL18	combined score (prob. 0.831)
# MEFV	NLRC4	combined score (prob. 0.883)
# MEFV	NLRC4	combined score (prob. 0.883)
# MEFV	IL1B	combined score (prob. 0.895)
# MEFV	IL1B	combined score (prob. 0.895)
# MEFV	NLRP1	combined score (prob. 0.918)
# MEFV	NLRP1	combined score (prob. 0.918)
# MEFV	PYCARD	combined score (prob. 0.981)
# MEFV	PYCARD	combined score (prob. 0.981)
# MEFV	PSTPIP1	combined score (prob. 0.999)
# MEFV	PSTPIP1	combined score (prob. 0.999)
# MEFV	CASP1	combined score (prob. 0.999)
# MEFV	CASP1	combined score (prob. 0.999)
# RIPK2	IL1B	combined score (prob. 0.605)
# RIPK2	IL1B	combined score (prob. 0.605)
# RIPK2	NLRC4	combined score (prob. 0.643)
# RIPK2	NLRC4	combined score (prob. 0.643)
# RIPK2	NLRP3	combined score (prob. 0.655)
# RIPK2	NLRP3	combined score (prob. 0.655)
# RIPK2	MAPK11	combined score (prob. 0.752)
# RIPK2	MAPK11	combined score (prob. 0.752)
# RIPK2	MAPK14	combined score (prob. 0.789)
# RIPK2	MAPK14	combined score (prob. 0.789)
# RIPK2	HSP90AB1	combined score (prob. 0.837)
# RIPK2	HSP90AB1	combined score (prob. 0.837)
# RIPK2	MAPK10	combined score (prob. 0.844)
# RIPK2	MAPK10	combined score (prob. 0.844)
# RIPK2	HSP90B1	combined score (prob. 0.846)
# RIPK2	HSP90B1	combined score (prob. 0.846)
# RIPK2	TAB3	combined score (prob. 0.862)
# RIPK2	TAB3	combined score (prob. 0.862)
# RIPK2	MAPK9	combined score (prob. 0.864)
# RIPK2	MAPK9	combined score (prob. 0.864)
# RIPK2	MAPK8	combined score (prob. 0.866)
# RIPK2	MAPK8	combined score (prob. 0.866)
# RIPK2	CASP1	combined score (prob. 0.929)
# RIPK2	CASP1	combined score (prob. 0.929)
# RIPK2	TAB2	combined score (prob. 0.934)
# RIPK2	TAB2	combined score (prob. 0.934)
# RIPK2	CARD9	combined score (prob. 0.935)
# RIPK2	CARD9	combined score (prob. 0.935)
# RIPK2	TNFAIP3	combined score (prob. 0.941)
# RIPK2	TNFAIP3	combined score (prob. 0.941)
# RIPK2	CHUK	combined score (prob. 0.941)
# RIPK2	CHUK	combined score (prob. 0.941)
# RIPK2	IKBKB	combined score (prob. 0.943)
# RIPK2	IKBKB	combined score (prob. 0.943)
# RIPK2	HSP90AA1	combined score (prob. 0.948)
# RIPK2	HSP90AA1	combined score (prob. 0.948)
# RIPK2	MAP3K7	combined score (prob. 0.949)
# RIPK2	MAP3K7	combined score (prob. 0.949)
# RIPK2	CASP8	combined score (prob. 0.951)
# RIPK2	CASP8	combined score (prob. 0.951)
# RIPK2	CARD6	combined score (prob. 0.971)
# RIPK2	CARD6	combined score (prob. 0.971)
# RIPK2	BIRC3	combined score (prob. 0.982)
# RIPK2	BIRC3	combined score (prob. 0.982)
# RIPK2	TRAF6	combined score (prob. 0.988)
# RIPK2	TRAF6	combined score (prob. 0.988)
# RIPK2	BIRC2	combined score (prob. 0.993)
# RIPK2	BIRC2	combined score (prob. 0.993)
# RIPK2	NOD2	combined score (prob. 0.999)
# RIPK2	NOD2	combined score (prob. 0.999)
# RIPK2	XIAP	combined score (prob. 0.999)
# RIPK2	XIAP	combined score (prob. 0.999)
# RIPK2	NOD1	combined score (prob. 0.999)
# RIPK2	NOD1	combined score (prob. 0.999)
# NOD1	IL6	combined score (prob. 0.612)
# NOD1	IL6	combined score (prob. 0.612)
# NOD1	PYCARD	combined score (prob. 0.635)
# NOD1	PYCARD	combined score (prob. 0.635)
# NOD1	CXCL8	combined score (prob. 0.646)
# NOD1	CXCL8	combined score (prob. 0.646)
# NOD1	IL18	combined score (prob. 0.676)
# NOD1	IL18	combined score (prob. 0.676)
# NOD1	MAPK11	combined score (prob. 0.700)
# NOD1	MAPK11	combined score (prob. 0.700)
# NOD1	IL1B	combined score (prob. 0.703)
# NOD1	IL1B	combined score (prob. 0.703)
# NOD1	TAB3	combined score (prob. 0.721)
# NOD1	TAB3	combined score (prob. 0.721)
# NOD1	MAP3K7	combined score (prob. 0.725)
# NOD1	MAP3K7	combined score (prob. 0.725)
# NOD1	CARD6	combined score (prob. 0.727)
# NOD1	CARD6	combined score (prob. 0.727)
# NOD1	MAPK14	combined score (prob. 0.731)
# NOD1	MAPK14	combined score (prob. 0.731)
# NOD1	TAB2	combined score (prob. 0.755)
# NOD1	TAB2	combined score (prob. 0.755)
# NOD1	NOD2	combined score (prob. 0.764)
# NOD1	NOD2	combined score (prob. 0.764)
# NOD1	CASP8	combined score (prob. 0.820)
# NOD1	CASP8	combined score (prob. 0.820)
# NOD1	TRAF6	combined score (prob. 0.828)
# NOD1	TRAF6	combined score (prob. 0.828)
# NOD1	CARD9	combined score (prob. 0.894)
# NOD1	CARD9	combined score (prob. 0.894)
# NOD1	TNFAIP3	combined score (prob. 0.924)
# NOD1	TNFAIP3	combined score (prob. 0.924)
# NOD1	BIRC3	combined score (prob. 0.942)
# NOD1	BIRC3	combined score (prob. 0.942)
# NOD1	CHUK	combined score (prob. 0.943)
# NOD1	CHUK	combined score (prob. 0.943)
# NOD1	IKBKB	combined score (prob. 0.943)
# NOD1	IKBKB	combined score (prob. 0.943)
# NOD1	BIRC2	combined score (prob. 0.944)
# NOD1	BIRC2	combined score (prob. 0.944)
# NOD1	SUGT1	combined score (prob. 0.950)
# NOD1	SUGT1	combined score (prob. 0.950)
# NOD1	CASP1	combined score (prob. 0.973)
# NOD1	CASP1	combined score (prob. 0.973)
# NOD1	HSP90AA1	combined score (prob. 0.977)
# NOD1	HSP90AA1	combined score (prob. 0.977)
# CCL2	IKBKB	combined score (prob. 0.602)
# CCL2	IKBKB	combined score (prob. 0.602)
# CCL2	MAPK3	combined score (prob. 0.634)
# CCL2	MAPK3	combined score (prob. 0.634)
# CCL2	NLRP3	combined score (prob. 0.636)
# CCL2	NLRP3	combined score (prob. 0.636)
# CCL2	CCL8	combined score (prob. 0.644)
# CCL2	CCL8	combined score (prob. 0.644)
# CCL2	CASP1	combined score (prob. 0.655)
# CCL2	CASP1	combined score (prob. 0.655)
# CCL2	NFKB1	combined score (prob. 0.892)
# CCL2	NFKB1	combined score (prob. 0.892)
# CCL2	RELA	combined score (prob. 0.950)
# CCL2	RELA	combined score (prob. 0.950)
# CCL2	IL18	combined score (prob. 0.976)
# CCL2	IL18	combined score (prob. 0.976)
# CCL2	CXCL2	combined score (prob. 0.984)
# CCL2	CXCL2	combined score (prob. 0.984)
# CCL2	CXCL1	combined score (prob. 0.989)
# CCL2	CXCL1	combined score (prob. 0.989)
# CCL2	IL1B	combined score (prob. 0.993)
# CCL2	IL1B	combined score (prob. 0.993)
# CCL2	IL6	combined score (prob. 0.994)
# CCL2	IL6	combined score (prob. 0.994)
# CCL2	CXCL8	combined score (prob. 0.995)
# CCL2	CXCL8	combined score (prob. 0.995)
# CCL13	CXCL8	combined score (prob. 0.641)
# CCL13	CXCL8	combined score (prob. 0.641)
# CCL13	CCL8	combined score (prob. 0.653)
# CCL13	CCL8	combined score (prob. 0.653)
# CCL13	IL1B	combined score (prob. 0.722)
# CCL13	IL1B	combined score (prob. 0.722)
# NFKB1	HSP90AB1	combined score (prob. 0.617)
# NFKB1	HSP90AB1	combined score (prob. 0.617)
# NFKB1	TAB3	combined score (prob. 0.719)
# NFKB1	TAB3	combined score (prob. 0.719)
# NFKB1	TNFAIP3	combined score (prob. 0.768)
# NFKB1	TNFAIP3	combined score (prob. 0.768)
# NFKB1	BIRC3	combined score (prob. 0.788)
# NFKB1	BIRC3	combined score (prob. 0.788)
# NFKB1	MAP3K7	combined score (prob. 0.836)
# NFKB1	MAP3K7	combined score (prob. 0.836)
# NFKB1	MAPK10	combined score (prob. 0.859)
# NFKB1	MAPK10	combined score (prob. 0.859)
# NFKB1	TAB2	combined score (prob. 0.864)
# NFKB1	TAB2	combined score (prob. 0.864)
# NFKB1	MAPK9	combined score (prob. 0.869)
# NFKB1	MAPK9	combined score (prob. 0.869)
# NFKB1	CXCL1	combined score (prob. 0.873)
# NFKB1	CXCL1	combined score (prob. 0.873)
# NFKB1	CXCL2	combined score (prob. 0.876)
# NFKB1	CXCL2	combined score (prob. 0.876)
# NFKB1	MAPK8	combined score (prob. 0.903)
# NFKB1	MAPK8	combined score (prob. 0.903)
# NFKB1	NLRP3	combined score (prob. 0.930)
# NFKB1	NLRP3	combined score (prob. 0.930)
# NFKB1	IL18	combined score (prob. 0.934)
# NFKB1	IL18	combined score (prob. 0.934)
# NFKB1	MAPK3	combined score (prob. 0.943)
# NFKB1	MAPK3	combined score (prob. 0.943)
# NFKB1	CASP8	combined score (prob. 0.946)
# NFKB1	CASP8	combined score (prob. 0.946)
# NFKB1	MAPK14	combined score (prob. 0.950)
# NFKB1	MAPK14	combined score (prob. 0.950)
# NFKB1	TRAF6	combined score (prob. 0.955)
# NFKB1	TRAF6	combined score (prob. 0.955)
# NFKB1	CXCL8	combined score (prob. 0.958)
# NFKB1	CXCL8	combined score (prob. 0.958)
# NFKB1	IL6	combined score (prob. 0.964)
# NFKB1	IL6	combined score (prob. 0.964)
# NFKB1	IL1B	combined score (prob. 0.967)
# NFKB1	IL1B	combined score (prob. 0.967)
# NFKB1	NFKBIB	combined score (prob. 0.991)
# NFKB1	NFKBIB	combined score (prob. 0.991)
# NFKB1	CHUK	combined score (prob. 0.999)
# NFKB1	CHUK	combined score (prob. 0.999)
# NFKB1	RELA	combined score (prob. 0.999)
# NFKB1	RELA	combined score (prob. 0.999)
# NFKB1	IKBKB	combined score (prob. 0.999)
# NFKB1	IKBKB	combined score (prob. 0.999)
# MAPK14	HSP90AA1	combined score (prob. 0.627)
# MAPK14	HSP90AA1	combined score (prob. 0.627)
# MAPK14	MAPK10	combined score (prob. 0.646)
# MAPK14	MAPK10	combined score (prob. 0.646)
# MAPK14	MAPK9	combined score (prob. 0.662)
# MAPK14	MAPK9	combined score (prob. 0.662)
# MAPK14	CARD9	combined score (prob. 0.688)
# MAPK14	CARD9	combined score (prob. 0.688)
# MAPK14	CASP8	combined score (prob. 0.698)
# MAPK14	CASP8	combined score (prob. 0.698)
# MAPK14	TAB3	combined score (prob. 0.732)
# MAPK14	TAB3	combined score (prob. 0.732)
# MAPK14	NOD2	combined score (prob. 0.739)
# MAPK14	NOD2	combined score (prob. 0.739)
# MAPK14	IL6	combined score (prob. 0.758)
# MAPK14	IL6	combined score (prob. 0.758)
# MAPK14	MAPK8	combined score (prob. 0.803)
# MAPK14	MAPK8	combined score (prob. 0.803)
# MAPK14	MAPK11	combined score (prob. 0.939)
# MAPK14	MAPK11	combined score (prob. 0.939)
# MAPK14	MAP3K7	combined score (prob. 0.943)
# MAPK14	MAP3K7	combined score (prob. 0.943)
# MAPK14	TAB2	combined score (prob. 0.947)
# MAPK14	TAB2	combined score (prob. 0.947)
# MAPK14	CXCL8	combined score (prob. 0.953)
# MAPK14	CXCL8	combined score (prob. 0.953)
# MAPK14	RELA	combined score (prob. 0.955)
# MAPK14	RELA	combined score (prob. 0.955)
# MAPK14	MAPK3	combined score (prob. 0.957)
# MAPK14	MAPK3	combined score (prob. 0.957)
# MAPK14	TRAF6	combined score (prob. 0.966)
# MAPK14	TRAF6	combined score (prob. 0.966)
# MAPK14	IL1B	combined score (prob. 0.972)
# MAPK14	IL1B	combined score (prob. 0.972)
# PYCARD	NOD2	combined score (prob. 0.636)
# PYCARD	NOD2	combined score (prob. 0.636)
# PYCARD	CARD9	combined score (prob. 0.651)
# PYCARD	CARD9	combined score (prob. 0.651)
# PYCARD	HSP90AB1	combined score (prob. 0.669)
# PYCARD	HSP90AB1	combined score (prob. 0.669)
# PYCARD	SUGT1	combined score (prob. 0.674)
# PYCARD	SUGT1	combined score (prob. 0.674)
# PYCARD	IKBKB	combined score (prob. 0.733)
# PYCARD	IKBKB	combined score (prob. 0.733)
# PYCARD	CHUK	combined score (prob. 0.739)
# PYCARD	CHUK	combined score (prob. 0.739)
# PYCARD	PSTPIP1	combined score (prob. 0.829)
# PYCARD	PSTPIP1	combined score (prob. 0.829)
# PYCARD	PYDC1	combined score (prob. 0.850)
# PYCARD	PYDC1	combined score (prob. 0.850)
# PYCARD	NLRP1	combined score (prob. 0.938)
# PYCARD	NLRP1	combined score (prob. 0.938)
# PYCARD	IL18	combined score (prob. 0.956)
# PYCARD	IL18	combined score (prob. 0.956)
# PYCARD	CARD8	combined score (prob. 0.974)
# PYCARD	CARD8	combined score (prob. 0.974)
# PYCARD	CASP8	combined score (prob. 0.979)
# PYCARD	CASP8	combined score (prob. 0.979)
# PYCARD	IL1B	combined score (prob. 0.980)
# PYCARD	IL1B	combined score (prob. 0.980)
# PYCARD	NLRC4	combined score (prob. 0.989)
# PYCARD	NLRC4	combined score (prob. 0.989)
# PYCARD	CASP5	combined score (prob. 0.996)
# PYCARD	CASP5	combined score (prob. 0.996)
# PYCARD	NLRP3	combined score (prob. 0.999)
# PYCARD	NLRP3	combined score (prob. 0.999)
# PYCARD	CASP1	combined score (prob. 0.999)
# PYCARD	CASP1	combined score (prob. 0.999)
# CARD6	CARD8	combined score (prob. 0.700)
# CARD6	CARD8	combined score (prob. 0.700)
# MAPK3	CXCL8	combined score (prob. 0.681)
# MAPK3	CXCL8	combined score (prob. 0.681)
# MAPK3	IL1B	combined score (prob. 0.712)
# MAPK3	IL1B	combined score (prob. 0.712)
# MAPK3	CARD9	combined score (prob. 0.822)
# MAPK3	CARD9	combined score (prob. 0.822)
# MAPK3	MAPK11	combined score (prob. 0.822)
# MAPK3	MAPK11	combined score (prob. 0.822)
# MAPK3	MAP3K7	combined score (prob. 0.849)
# MAPK3	MAP3K7	combined score (prob. 0.849)
# MAPK3	CCL11	combined score (prob. 0.929)
# MAPK3	CCL11	combined score (prob. 0.929)
# MAPK3	MAPK8	combined score (prob. 0.934)
# MAPK3	MAPK8	combined score (prob. 0.934)
# MAPK3	IL18	combined score (prob. 0.941)
# MAPK3	IL18	combined score (prob. 0.941)
# MAPK3	RELA	combined score (prob. 0.946)
# MAPK3	RELA	combined score (prob. 0.946)
# MAPK3	HSP90AB1	combined score (prob. 0.953)
# MAPK3	HSP90AB1	combined score (prob. 0.953)
# MAPK3	IL6	combined score (prob. 0.973)
# MAPK3	IL6	combined score (prob. 0.973)
# MAPK3	CASP8	combined score (prob. 0.980)
# MAPK3	CASP8	combined score (prob. 0.980)
# MAPK3	HSP90AA1	combined score (prob. 0.990)
# MAPK3	HSP90AA1	combined score (prob. 0.990)
# IL1B	HSP90AA1	combined score (prob. 0.611)
# IL1B	HSP90AA1	combined score (prob. 0.611)
# IL1B	MAP3K7	combined score (prob. 0.623)
# IL1B	MAP3K7	combined score (prob. 0.623)
# IL1B	MAPK8	combined score (prob. 0.658)
# IL1B	MAPK8	combined score (prob. 0.658)
# IL1B	CCL8	combined score (prob. 0.691)
# IL1B	CCL8	combined score (prob. 0.691)
# IL1B	TNFAIP3	combined score (prob. 0.725)
# IL1B	TNFAIP3	combined score (prob. 0.725)
# IL1B	IKBKB	combined score (prob. 0.730)
# IL1B	IKBKB	combined score (prob. 0.730)
# IL1B	NLRP1	combined score (prob. 0.761)
# IL1B	NLRP1	combined score (prob. 0.761)
# IL1B	CHUK	combined score (prob. 0.776)
# IL1B	CHUK	combined score (prob. 0.776)
# IL1B	NOD2	combined score (prob. 0.783)
# IL1B	NOD2	combined score (prob. 0.783)
# IL1B	CCL7	combined score (prob. 0.788)
# IL1B	CCL7	combined score (prob. 0.788)
# IL1B	CASP5	combined score (prob. 0.810)
# IL1B	CASP5	combined score (prob. 0.810)
# IL1B	CCL11	combined score (prob. 0.828)
# IL1B	CCL11	combined score (prob. 0.828)
# IL1B	NLRC4	combined score (prob. 0.840)
# IL1B	NLRC4	combined score (prob. 0.840)
# IL1B	MAPK11	combined score (prob. 0.943)
# IL1B	MAPK11	combined score (prob. 0.943)
# IL1B	CASP8	combined score (prob. 0.975)
# IL1B	CASP8	combined score (prob. 0.975)
# IL1B	RELA	combined score (prob. 0.978)
# IL1B	RELA	combined score (prob. 0.978)
# IL1B	TRAF6	combined score (prob. 0.982)
# IL1B	TRAF6	combined score (prob. 0.982)
# IL1B	NLRP3	combined score (prob. 0.986)
# IL1B	NLRP3	combined score (prob. 0.986)
# IL1B	CXCL2	combined score (prob. 0.994)
# IL1B	CXCL2	combined score (prob. 0.994)
# IL1B	IL18	combined score (prob. 0.994)
# IL1B	IL18	combined score (prob. 0.994)
# IL1B	CXCL1	combined score (prob. 0.996)
# IL1B	CXCL1	combined score (prob. 0.996)
# IL1B	IL6	combined score (prob. 0.997)
# IL1B	IL6	combined score (prob. 0.997)
# IL1B	CXCL8	combined score (prob. 0.998)
# IL1B	CXCL8	combined score (prob. 0.998)
# IL1B	CASP1	combined score (prob. 0.999)
# IL1B	CASP1	combined score (prob. 0.999)
# BIRC3	CASP1	combined score (prob. 0.726)
# BIRC3	CASP1	combined score (prob. 0.726)
# BIRC3	TAB3	combined score (prob. 0.740)
# BIRC3	TAB3	combined score (prob. 0.740)
# BIRC3	TAB2	combined score (prob. 0.800)
# BIRC3	TAB2	combined score (prob. 0.800)
# BIRC3	MAP3K7	combined score (prob. 0.818)
# BIRC3	MAP3K7	combined score (prob. 0.818)
# BIRC3	CHUK	combined score (prob. 0.891)
# BIRC3	CHUK	combined score (prob. 0.891)
# BIRC3	TNFAIP3	combined score (prob. 0.908)
# BIRC3	TNFAIP3	combined score (prob. 0.908)
# BIRC3	IKBKB	combined score (prob. 0.919)
# BIRC3	IKBKB	combined score (prob. 0.919)
# BIRC3	BIRC2	combined score (prob. 0.933)
# BIRC3	BIRC2	combined score (prob. 0.933)
# BIRC3	XIAP	combined score (prob. 0.953)
# BIRC3	XIAP	combined score (prob. 0.953)
# BIRC3	NOD2	combined score (prob. 0.960)
# BIRC3	NOD2	combined score (prob. 0.960)
# BIRC3	RELA	combined score (prob. 0.984)
# BIRC3	RELA	combined score (prob. 0.984)
# BIRC3	TRAF6	combined score (prob. 0.986)
# BIRC3	TRAF6	combined score (prob. 0.986)
# BIRC3	CASP8	combined score (prob. 0.990)
# BIRC3	CASP8	combined score (prob. 0.990)
# IL18	CASP8	combined score (prob. 0.608)
# IL18	CASP8	combined score (prob. 0.608)
# IL18	CCL7	combined score (prob. 0.616)
# IL18	CCL7	combined score (prob. 0.616)
# IL18	CCL11	combined score (prob. 0.687)
# IL18	CCL11	combined score (prob. 0.687)
# IL18	NOD2	combined score (prob. 0.689)
# IL18	NOD2	combined score (prob. 0.689)
# IL18	CASP5	combined score (prob. 0.790)
# IL18	CASP5	combined score (prob. 0.790)
# IL18	NLRC4	combined score (prob. 0.868)
# IL18	NLRC4	combined score (prob. 0.868)
# IL18	NLRP1	combined score (prob. 0.880)
# IL18	NLRP1	combined score (prob. 0.880)
# IL18	MAPK9	combined score (prob. 0.919)
# IL18	MAPK9	combined score (prob. 0.919)
# IL18	NLRP3	combined score (prob. 0.931)
# IL18	NLRP3	combined score (prob. 0.931)
# IL18	MAPK8	combined score (prob. 0.934)
# IL18	MAPK8	combined score (prob. 0.934)
# IL18	RELA	combined score (prob. 0.937)
# IL18	RELA	combined score (prob. 0.937)
# IL18	CXCL2	combined score (prob. 0.967)
# IL18	CXCL2	combined score (prob. 0.967)
# IL18	CXCL1	combined score (prob. 0.975)
# IL18	CXCL1	combined score (prob. 0.975)
# IL18	CXCL8	combined score (prob. 0.986)
# IL18	CXCL8	combined score (prob. 0.986)
# IL18	IL6	combined score (prob. 0.988)
# IL18	IL6	combined score (prob. 0.988)
# IL18	CASP1	combined score (prob. 0.997)
# IL18	CASP1	combined score (prob. 0.997)
# HSP90B1	BIRC2	combined score (prob. 0.653)
# HSP90B1	BIRC2	combined score (prob. 0.653)
# HSP90B1	HSP90AB1	combined score (prob. 0.853)
# HSP90B1	HSP90AB1	combined score (prob. 0.853)
# HSP90B1	HSP90AA1	combined score (prob. 0.873)
# HSP90B1	HSP90AA1	combined score (prob. 0.873)
# HSP90B1	SUGT1	combined score (prob. 0.963)
# HSP90B1	SUGT1	combined score (prob. 0.963)
# NOD2	PSTPIP1	combined score (prob. 0.609)
# NOD2	PSTPIP1	combined score (prob. 0.609)
# NOD2	CARD8	combined score (prob. 0.671)
# NOD2	CARD8	combined score (prob. 0.671)
# NOD2	MAPK11	combined score (prob. 0.680)
# NOD2	MAPK11	combined score (prob. 0.680)
# NOD2	CXCL8	combined score (prob. 0.681)
# NOD2	CXCL8	combined score (prob. 0.681)
# NOD2	IL6	combined score (prob. 0.690)
# NOD2	IL6	combined score (prob. 0.690)
# NOD2	TAB3	combined score (prob. 0.722)
# NOD2	TAB3	combined score (prob. 0.722)
# NOD2	NLRC4	combined score (prob. 0.748)
# NOD2	NLRC4	combined score (prob. 0.748)
# NOD2	TAB2	combined score (prob. 0.758)
# NOD2	TAB2	combined score (prob. 0.758)
# NOD2	HSP90AA1	combined score (prob. 0.850)
# NOD2	HSP90AA1	combined score (prob. 0.850)
# NOD2	TRAF6	combined score (prob. 0.880)
# NOD2	TRAF6	combined score (prob. 0.880)
# NOD2	NLRP1	combined score (prob. 0.916)
# NOD2	NLRP1	combined score (prob. 0.916)
# NOD2	XIAP	combined score (prob. 0.917)
# NOD2	XIAP	combined score (prob. 0.917)
# NOD2	MAP3K7	combined score (prob. 0.927)
# NOD2	MAP3K7	combined score (prob. 0.927)
# NOD2	IKBKB	combined score (prob. 0.943)
# NOD2	IKBKB	combined score (prob. 0.943)
# NOD2	CHUK	combined score (prob. 0.944)
# NOD2	CHUK	combined score (prob. 0.944)
# NOD2	TNFAIP3	combined score (prob. 0.961)
# NOD2	TNFAIP3	combined score (prob. 0.961)
# NOD2	BIRC2	combined score (prob. 0.966)
# NOD2	BIRC2	combined score (prob. 0.966)
# NOD2	CASP1	combined score (prob. 0.990)
# NOD2	CASP1	combined score (prob. 0.990)
# NOD2	CARD9	combined score (prob. 0.994)
# NOD2	CARD9	combined score (prob. 0.994)
# NOD2	ERBB2IP	combined score (prob. 0.997)
# NOD2	ERBB2IP	combined score (prob. 0.997)
# CCL11	CXCL2	combined score (prob. 0.723)
# CCL11	CXCL2	combined score (prob. 0.723)
# CCL11	CXCL8	combined score (prob. 0.818)
# CCL11	CXCL8	combined score (prob. 0.818)
# CCL11	IL6	combined score (prob. 0.830)
# CCL11	IL6	combined score (prob. 0.830)
# CCL11	CXCL1	combined score (prob. 0.840)
# CCL11	CXCL1	combined score (prob. 0.840)
# PYDC1	NLRP3	combined score (prob. 0.601)
# PYDC1	NLRP3	combined score (prob. 0.601)
# PYDC1	IKBKB	combined score (prob. 0.619)
# PYDC1	IKBKB	combined score (prob. 0.619)
# PYDC1	NLRP1	combined score (prob. 0.652)
# PYDC1	NLRP1	combined score (prob. 0.652)
# PYDC1	CHUK	combined score (prob. 0.735)
# PYDC1	CHUK	combined score (prob. 0.735)
# CXCL8	CHUK	combined score (prob. 0.601)
# CXCL8	CHUK	combined score (prob. 0.601)
# CXCL8	TRAF6	combined score (prob. 0.624)
# CXCL8	TRAF6	combined score (prob. 0.624)
# CXCL8	IKBKB	combined score (prob. 0.636)
# CXCL8	IKBKB	combined score (prob. 0.636)
# CXCL8	NLRP3	combined score (prob. 0.650)
# CXCL8	NLRP3	combined score (prob. 0.650)
# CXCL8	CASP1	combined score (prob. 0.722)
# CXCL8	CASP1	combined score (prob. 0.722)
# CXCL8	TNFAIP3	combined score (prob. 0.772)
# CXCL8	TNFAIP3	combined score (prob. 0.772)
# CXCL8	CCL8	combined score (prob. 0.780)
# CXCL8	CCL8	combined score (prob. 0.780)
# CXCL8	CCL7	combined score (prob. 0.842)
# CXCL8	CCL7	combined score (prob. 0.842)
# CXCL8	CXCL2	combined score (prob. 0.884)
# CXCL8	CXCL2	combined score (prob. 0.884)
# CXCL8	CXCL1	combined score (prob. 0.897)
# CXCL8	CXCL1	combined score (prob. 0.897)
# CXCL8	MAPK11	combined score (prob. 0.923)
# CXCL8	MAPK11	combined score (prob. 0.923)
# CXCL8	RELA	combined score (prob. 0.991)
# CXCL8	RELA	combined score (prob. 0.991)
# CXCL8	IL6	combined score (prob. 0.997)
# CXCL8	IL6	combined score (prob. 0.997)
# NFKBIB	MAP3K7	combined score (prob. 0.795)
# NFKBIB	MAP3K7	combined score (prob. 0.795)
# NFKBIB	TRAF6	combined score (prob. 0.839)
# NFKBIB	TRAF6	combined score (prob. 0.839)
# NFKBIB	IKBKB	combined score (prob. 0.995)
# NFKBIB	IKBKB	combined score (prob. 0.995)
# NFKBIB	CHUK	combined score (prob. 0.997)
# NFKBIB	CHUK	combined score (prob. 0.997)
# NFKBIB	RELA	combined score (prob. 0.999)
# NFKBIB	RELA	combined score (prob. 0.999)
# MAPK11	MAPK10	combined score (prob. 0.644)
# MAPK11	MAPK10	combined score (prob. 0.644)
# MAPK11	MAPK8	combined score (prob. 0.645)
# MAPK11	MAPK8	combined score (prob. 0.645)
# MAPK11	MAPK9	combined score (prob. 0.654)
# MAPK11	MAPK9	combined score (prob. 0.654)
# MAPK11	CARD9	combined score (prob. 0.668)
# MAPK11	CARD9	combined score (prob. 0.668)
# MAPK11	TAB3	combined score (prob. 0.674)
# MAPK11	TAB3	combined score (prob. 0.674)
# MAPK11	TAB2	combined score (prob. 0.916)
# MAPK11	TAB2	combined score (prob. 0.916)
# MAPK11	MAP3K7	combined score (prob. 0.924)
# MAPK11	MAP3K7	combined score (prob. 0.924)
# MAPK11	TRAF6	combined score (prob. 0.938)
# MAPK11	TRAF6	combined score (prob. 0.938)
# HSP90AA1	NLRC4	combined score (prob. 0.620)
# HSP90AA1	NLRC4	combined score (prob. 0.620)
# HSP90AA1	ERBB2IP	combined score (prob. 0.719)
# HSP90AA1	ERBB2IP	combined score (prob. 0.719)
# HSP90AA1	IL6	combined score (prob. 0.776)
# HSP90AA1	IL6	combined score (prob. 0.776)
# HSP90AA1	HSP90AB1	combined score (prob. 0.994)
# HSP90AA1	HSP90AB1	combined score (prob. 0.994)
# HSP90AA1	IKBKB	combined score (prob. 0.995)
# HSP90AA1	IKBKB	combined score (prob. 0.995)
# HSP90AA1	CHUK	combined score (prob. 0.996)
# HSP90AA1	CHUK	combined score (prob. 0.996)
# HSP90AA1	NLRP3	combined score (prob. 0.996)
# HSP90AA1	NLRP3	combined score (prob. 0.996)
# HSP90AA1	SUGT1	combined score (prob. 0.999)
# HSP90AA1	SUGT1	combined score (prob. 0.999)
# NLRP3	PSTPIP1	combined score (prob. 0.641)
# NLRP3	PSTPIP1	combined score (prob. 0.641)
# NLRP3	IL6	combined score (prob. 0.785)
# NLRP3	IL6	combined score (prob. 0.785)
# NLRP3	HSP90AB1	combined score (prob. 0.850)
# NLRP3	HSP90AB1	combined score (prob. 0.850)
# NLRP3	SUGT1	combined score (prob. 0.912)
# NLRP3	SUGT1	combined score (prob. 0.912)
# NLRP3	CASP8	combined score (prob. 0.915)
# NLRP3	CASP8	combined score (prob. 0.915)
# NLRP3	NLRP1	combined score (prob. 0.925)
# NLRP3	NLRP1	combined score (prob. 0.925)
# NLRP3	RELA	combined score (prob. 0.931)
# NLRP3	RELA	combined score (prob. 0.931)
# NLRP3	CASP5	combined score (prob. 0.985)
# NLRP3	CASP5	combined score (prob. 0.985)
# NLRP3	CARD8	combined score (prob. 0.994)
# NLRP3	CARD8	combined score (prob. 0.994)
# NLRP3	NLRC4	combined score (prob. 0.998)
# NLRP3	NLRC4	combined score (prob. 0.998)
# NLRP3	CASP1	combined score (prob. 0.999)
# NLRP3	CASP1	combined score (prob. 0.999)
# CASP8	IL6	combined score (prob. 0.706)
# CASP8	IL6	combined score (prob. 0.706)
# CASP8	MAPK8	combined score (prob. 0.720)
# CASP8	MAPK8	combined score (prob. 0.720)
# CASP8	TNFAIP3	combined score (prob. 0.811)
# CASP8	TNFAIP3	combined score (prob. 0.811)
# CASP8	CASP1	combined score (prob. 0.916)
# CASP8	CASP1	combined score (prob. 0.916)
# CASP8	NLRC4	combined score (prob. 0.952)
# CASP8	NLRC4	combined score (prob. 0.952)
# CASP8	RELA	combined score (prob. 0.956)
# CASP8	RELA	combined score (prob. 0.956)
# CASP8	IKBKB	combined score (prob. 0.969)
# CASP8	IKBKB	combined score (prob. 0.969)
# CASP8	XIAP	combined score (prob. 0.970)
# CASP8	XIAP	combined score (prob. 0.970)
# CASP8	CARD9	combined score (prob. 0.980)
# CASP8	CARD9	combined score (prob. 0.980)
# CASP8	CHUK	combined score (prob. 0.987)
# CASP8	CHUK	combined score (prob. 0.987)
# CASP8	TRAF6	combined score (prob. 0.995)
# CASP8	TRAF6	combined score (prob. 0.995)
# CASP8	BIRC2	combined score (prob. 0.997)
# CASP8	BIRC2	combined score (prob. 0.997)
# MAPK10	CARD9	combined score (prob. 0.800)
# MAPK10	CARD9	combined score (prob. 0.800)
# MAPK10	RELA	combined score (prob. 0.843)
# MAPK10	RELA	combined score (prob. 0.843)
# MAPK10	MAP3K7	combined score (prob. 0.895)
# MAPK10	MAP3K7	combined score (prob. 0.895)
# MAPK10	MAPK8	combined score (prob. 0.904)
# MAPK10	MAPK8	combined score (prob. 0.904)
# MAPK10	TRAF6	combined score (prob. 0.929)
# MAPK10	TRAF6	combined score (prob. 0.929)
# MAPK10	MAPK9	combined score (prob. 0.929)
# MAPK10	MAPK9	combined score (prob. 0.929)
# TAB2	RELA	combined score (prob. 0.805)
# TAB2	RELA	combined score (prob. 0.805)
# TAB2	BIRC2	combined score (prob. 0.911)
# TAB2	BIRC2	combined score (prob. 0.911)
# TAB2	TAB3	combined score (prob. 0.938)
# TAB2	TAB3	combined score (prob. 0.938)
# TAB2	TNFAIP3	combined score (prob. 0.946)
# TAB2	TNFAIP3	combined score (prob. 0.946)
# TAB2	XIAP	combined score (prob. 0.952)
# TAB2	XIAP	combined score (prob. 0.952)
# TAB2	IKBKB	combined score (prob. 0.986)
# TAB2	IKBKB	combined score (prob. 0.986)
# TAB2	CHUK	combined score (prob. 0.988)
# TAB2	CHUK	combined score (prob. 0.988)
# TAB2	MAP3K7	combined score (prob. 0.999)
# TAB2	MAP3K7	combined score (prob. 0.999)
# TAB2	TRAF6	combined score (prob. 0.999)
# TAB2	TRAF6	combined score (prob. 0.999)
# MAP3K7	BIRC2	combined score (prob. 0.854)
# MAP3K7	BIRC2	combined score (prob. 0.854)
# MAP3K7	MAPK9	combined score (prob. 0.892)
# MAP3K7	MAPK9	combined score (prob. 0.892)
# MAP3K7	TNFAIP3	combined score (prob. 0.936)
# MAP3K7	TNFAIP3	combined score (prob. 0.936)
# MAP3K7	RELA	combined score (prob. 0.937)
# MAP3K7	RELA	combined score (prob. 0.937)
# MAP3K7	MAPK8	combined score (prob. 0.948)
# MAP3K7	MAPK8	combined score (prob. 0.948)
# MAP3K7	XIAP	combined score (prob. 0.984)
# MAP3K7	XIAP	combined score (prob. 0.984)
# MAP3K7	CHUK	combined score (prob. 0.990)
# MAP3K7	CHUK	combined score (prob. 0.990)
# MAP3K7	IKBKB	combined score (prob. 0.993)
# MAP3K7	IKBKB	combined score (prob. 0.993)
# MAP3K7	TAB3	combined score (prob. 0.994)
# MAP3K7	TAB3	combined score (prob. 0.994)
# MAP3K7	TRAF6	combined score (prob. 0.999)
# MAP3K7	TRAF6	combined score (prob. 0.999)
# CHUK	IL6	combined score (prob. 0.689)
# CHUK	IL6	combined score (prob. 0.689)
# CHUK	HSP90AB1	combined score (prob. 0.740)
# CHUK	HSP90AB1	combined score (prob. 0.740)
# CHUK	XIAP	combined score (prob. 0.837)
# CHUK	XIAP	combined score (prob. 0.837)
# CHUK	CARD9	combined score (prob. 0.850)
# CHUK	CARD9	combined score (prob. 0.850)
# CHUK	BIRC2	combined score (prob. 0.943)
# CHUK	BIRC2	combined score (prob. 0.943)
# CHUK	TNFAIP3	combined score (prob. 0.959)
# CHUK	TNFAIP3	combined score (prob. 0.959)
# CHUK	TAB3	combined score (prob. 0.973)
# CHUK	TAB3	combined score (prob. 0.973)
# CHUK	IKBKB	combined score (prob. 0.992)
# CHUK	IKBKB	combined score (prob. 0.992)
# CHUK	TRAF6	combined score (prob. 0.997)
# CHUK	TRAF6	combined score (prob. 0.997)
# CHUK	RELA	combined score (prob. 0.998)
# CHUK	RELA	combined score (prob. 0.998)
# XIAP	CASP1	combined score (prob. 0.712)
# XIAP	CASP1	combined score (prob. 0.712)
# XIAP	TNFAIP3	combined score (prob. 0.720)
# XIAP	TNFAIP3	combined score (prob. 0.720)
# XIAP	TAB3	combined score (prob. 0.770)
# XIAP	TAB3	combined score (prob. 0.770)
# XIAP	TRAF6	combined score (prob. 0.831)
# XIAP	TRAF6	combined score (prob. 0.831)
# XIAP	IKBKB	combined score (prob. 0.841)
# XIAP	IKBKB	combined score (prob. 0.841)
# XIAP	BIRC2	combined score (prob. 0.989)
# XIAP	BIRC2	combined score (prob. 0.989)
# HSP90AB1	IKBKB	combined score (prob. 0.878)
# HSP90AB1	IKBKB	combined score (prob. 0.878)
# HSP90AB1	SUGT1	combined score (prob. 0.999)
# HSP90AB1	SUGT1	combined score (prob. 0.999)
# CARD9	TRAF6	combined score (prob. 0.690)
# CARD9	TRAF6	combined score (prob. 0.690)
# CARD9	MAPK9	combined score (prob. 0.807)
# CARD9	MAPK9	combined score (prob. 0.807)
# CARD9	MAPK8	combined score (prob. 0.820)
# CARD9	MAPK8	combined score (prob. 0.820)
# CARD9	IKBKB	combined score (prob. 0.862)
# CARD9	IKBKB	combined score (prob. 0.862)
# SUGT1	ERBB2IP	combined score (prob. 0.639)
# SUGT1	ERBB2IP	combined score (prob. 0.639)
# CCL7	CXCL2	combined score (prob. 0.758)
# CCL7	CXCL2	combined score (prob. 0.758)
# CCL7	IL6	combined score (prob. 0.801)
# CCL7	IL6	combined score (prob. 0.801)
# CCL7	CXCL1	combined score (prob. 0.826)
# CCL7	CXCL1	combined score (prob. 0.826)
# TAB3	RELA	combined score (prob. 0.761)
# TAB3	RELA	combined score (prob. 0.761)
# TAB3	BIRC2	combined score (prob. 0.809)
# TAB3	BIRC2	combined score (prob. 0.809)
# TAB3	TNFAIP3	combined score (prob. 0.934)
# TAB3	TNFAIP3	combined score (prob. 0.934)
# TAB3	IKBKB	combined score (prob. 0.972)
# TAB3	IKBKB	combined score (prob. 0.972)
# TAB3	TRAF6	combined score (prob. 0.993)
# TAB3	TRAF6	combined score (prob. 0.993)
# CARD8	NLRC4	combined score (prob. 0.875)
# CARD8	NLRC4	combined score (prob. 0.875)
# CARD8	NLRP1	combined score (prob. 0.912)
# CARD8	NLRP1	combined score (prob. 0.912)
# CARD8	CASP5	combined score (prob. 0.979)
# CARD8	CASP5	combined score (prob. 0.979)
# CARD8	CASP1	combined score (prob. 0.996)
# CARD8	CASP1	combined score (prob. 0.996)
# CASP5	CASP1	combined score (prob. 0.937)
# CASP5	CASP1	combined score (prob. 0.937)
# CASP5	NLRC4	combined score (prob. 0.943)
# CASP5	NLRC4	combined score (prob. 0.943)
# CASP5	NLRP1	combined score (prob. 0.998)
# CASP5	NLRP1	combined score (prob. 0.998)
# CCL8	IL6	combined score (prob. 0.692)
# CCL8	IL6	combined score (prob. 0.692)
# CCL8	CXCL1	combined score (prob. 0.697)
# CCL8	CXCL1	combined score (prob. 0.697)
# CCL8	CXCL2	combined score (prob. 0.706)
# CCL8	CXCL2	combined score (prob. 0.706)
# MAPK8	IL6	combined score (prob. 0.668)
# MAPK8	IL6	combined score (prob. 0.668)
# MAPK8	RELA	combined score (prob. 0.913)
# MAPK8	RELA	combined score (prob. 0.913)
# MAPK8	TRAF6	combined score (prob. 0.968)
# MAPK8	TRAF6	combined score (prob. 0.968)
# MAPK8	MAPK9	combined score (prob. 0.980)
# MAPK8	MAPK9	combined score (prob. 0.980)
# CXCL1	CASP1	combined score (prob. 0.602)
# CXCL1	CASP1	combined score (prob. 0.602)
# CXCL1	TNFAIP3	combined score (prob. 0.652)
# CXCL1	TNFAIP3	combined score (prob. 0.652)
# CXCL1	RELA	combined score (prob. 0.889)
# CXCL1	RELA	combined score (prob. 0.889)
# CXCL1	CXCL2	combined score (prob. 0.960)
# CXCL1	CXCL2	combined score (prob. 0.960)
# CXCL1	IL6	combined score (prob. 0.996)
# CXCL1	IL6	combined score (prob. 0.996)
# RELA	TNFAIP3	combined score (prob. 0.656)
# RELA	TNFAIP3	combined score (prob. 0.656)
# RELA	MAPK9	combined score (prob. 0.863)
# RELA	MAPK9	combined score (prob. 0.863)
# RELA	CXCL2	combined score (prob. 0.906)
# RELA	CXCL2	combined score (prob. 0.906)
# RELA	TRAF6	combined score (prob. 0.961)
# RELA	TRAF6	combined score (prob. 0.961)
# RELA	IL6	combined score (prob. 0.976)
# RELA	IL6	combined score (prob. 0.976)
# RELA	BIRC2	combined score (prob. 0.978)
# RELA	BIRC2	combined score (prob. 0.978)
# RELA	IKBKB	combined score (prob. 0.998)
# RELA	IKBKB	combined score (prob. 0.998)
# NLRC4	NLRP1	combined score (prob. 0.996)
# NLRC4	NLRP1	combined score (prob. 0.996)
# NLRC4	CASP1	combined score (prob. 0.999)
# NLRC4	CASP1	combined score (prob. 0.999)
# IL6	TNFAIP3	combined score (prob. 0.642)
# IL6	TNFAIP3	combined score (prob. 0.642)
# IL6	TRAF6	combined score (prob. 0.730)
# IL6	TRAF6	combined score (prob. 0.730)
# IL6	IKBKB	combined score (prob. 0.733)
# IL6	IKBKB	combined score (prob. 0.733)
# IL6	CASP1	combined score (prob. 0.822)
# IL6	CASP1	combined score (prob. 0.822)
# IL6	CXCL2	combined score (prob. 0.995)
# IL6	CXCL2	combined score (prob. 0.995)
# MAPK9	TRAF6	combined score (prob. 0.941)
# MAPK9	TRAF6	combined score (prob. 0.941)
# CXCL2	TNFAIP3	combined score (prob. 0.647)
# CXCL2	TNFAIP3	combined score (prob. 0.647)
# IKBKB	BIRC2	combined score (prob. 0.895)
# IKBKB	BIRC2	combined score (prob. 0.895)
# IKBKB	TNFAIP3	combined score (prob. 0.984)
# IKBKB	TNFAIP3	combined score (prob. 0.984)
# IKBKB	TRAF6	combined score (prob. 0.999)
# IKBKB	TRAF6	combined score (prob. 0.999)
# CASP1	BIRC2	combined score (prob. 0.747)
# CASP1	BIRC2	combined score (prob. 0.747)
# CASP1	CARD18	combined score (prob. 0.949)
# CASP1	CARD18	combined score (prob. 0.949)
# CASP1	NLRP1	combined score (prob. 0.999)
# CASP1	NLRP1	combined score (prob. 0.999)
# TRAF6	BIRC2	combined score (prob. 0.979)
# TRAF6	BIRC2	combined score (prob. 0.979)
# TRAF6	TNFAIP3	combined score (prob. 0.993)
# TRAF6	TNFAIP3	combined score (prob. 0.993)
# BIRC2	TNFAIP3	combined score (prob. 0.901)
# BIRC2	TNFAIP3	combined score (prob. 0.901)

# %% [markdown]
# # Save output to dataframe
#
# use `df.loc[len(df)]` to append list of equal length to end of df LIFESAVER

# %%
import pandas as pd

output_format = "tsv-no-header"
method = "network"

## Construct URL
request_url = "/".join([string_api_url, output_format, method])

# set confience_score between 0-1
confidence_score = 0.6

## Set parameters
my_genes = string_id

params = {
    "identifiers" : "%0d".join(my_genes), # your protein
    "species" : species_id, # species NCBI identifier 
    "caller_identity" : "Research_Project" # your app name
}

""" other params
"required_score" :	# threshold of significance to include a interaction, a number between 0 and 1000 (default depends on the network)
    "network_type" :	# network type: functional (default), physical
    "add_nodes"	: # adds a number of proteins with to the network based on their confidence score
    "show_query_node_labels" :	# when available use submitted names in the preferredName column when (0 or 1) (default:0)
    """

## Call STRING
response = requests.post(request_url, data=params)

# creates data frame with colume headins 
patient_df = pd.DataFrame(columns = ['stringId_A', 'stringId_B', 'preferredName_A', 'preferredName_B', 'ncbiTaxonId', 'score', 'nscore', 'fscore', 'pscore', 'ascore', 'escore', 'dscore', 'tscore'])

for line in response.text.strip().split("\n"):
    # seperates each line into list
    l = line.strip().split("\t")
    
    # adds each line to the data frame 
    patient_df.loc[len(patient_df)] = l
 
patient_df.head()
# Out:
#              stringId_A            stringId_B preferredName_A preferredName_B  \
# 0  9606.ENSP00000200457  9606.ENSP00000222823           TRIP6            NOD1
# 1  9606.ENSP00000200457  9606.ENSP00000222823           TRIP6            NOD1
# 2  9606.ENSP00000200457  9606.ENSP00000384273           TRIP6            RELA
# 3  9606.ENSP00000200457  9606.ENSP00000384273           TRIP6            RELA
# 4  9606.ENSP00000200457  9606.ENSP00000220751           TRIP6           RIPK2
#
#   ncbiTaxonId  score nscore fscore pscore ascore escore dscore tscore
# 0        9606  0.441      0      0      0      0      0      0  0.441
# 1        9606  0.441      0      0      0      0      0      0  0.441
# 2        9606   0.53      0      0      0  0.059   0.27      0   0.37
# 3        9606   0.53      0      0      0  0.059   0.27      0   0.37
# 4        9606   0.84      0      0      0  0.079  0.078    0.8  0.171

# %% [markdown]
# # Enrichment analysis from string API

# %% [markdown]
# # Functional annotation from string API

# %% [markdown]
# # PPI enrichment
# Tests if your network has more interactions than expected

# %% [markdown]
# # Get string clusters for a patient

# %% [markdown]
# # Test

# %%
import get_patient
import pandas as pd
from get_data import genepy_norm_loeuf

genepy_norm_loeuf.head()
# Out:
#             A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT     A4GNT  \
# Samid
# AP0013  0.097623  0.027245  0.107498  0.011378  0.041579  0.028535  0.055493
# AP0030  0.134882  0.000000  0.018830  0.064448  0.000000  0.015138  0.022460
# AP0045  0.107196  0.000000  0.025388  0.034014  0.000000  0.007506  0.030282
# AP0046  0.179652  0.000000  0.025081  0.118953  0.014841  0.007415  0.029915
# AP0055  0.091878  0.000000  0.038677  0.072722  0.008690  0.007527  0.080610
#
#             AAAS  AACS     AADAC  ...  ZW10    ZWILCH     ZWINT  ZXDA  \
# Samid                             ...
# AP0013  0.000000   0.0  0.000000  ...   0.0  0.026087  0.010998   0.0
# AP0030  0.018639   0.0  0.004263  ...   0.0  0.011772  0.007656   0.0
# AP0045  0.000000   0.0  0.121555  ...   0.0  0.000000  0.010323   0.0
# AP0046  0.024826   0.0  0.000000  ...   0.0  0.000000  0.010197   0.0
# AP0055  0.025200   0.0  0.121888  ...   0.0  0.015916  0.010351   0.0
#
#             ZXDC    ZYG11A    ZYG11B  ZYX     ZZEF1      ZZZ3
# Samid
# AP0013  0.008628  0.000000  0.044287  0.0  0.340699  0.000000
# AP0030  0.009848  0.000000  0.030830  0.0  0.284207  0.000000
# AP0045  0.008098  0.009520  0.000000  0.0  0.014009  0.233638
# AP0046  0.008000  0.009405  0.048775  0.0  0.013839  0.000000
# AP0055  0.008120  0.009546  0.000000  0.0  0.559744  0.234278
#
# [5 rows x 16794 columns]

# %%
test1 = get_patient_as_Series(genepy_norm_loeuf, 1).sort_values(ascending=False).iloc[:2000].to_frame().T
test1
df1 = genepy_norm_loeuf

test2 = get_patient.get_patient_as_Series(df1, 0).sort_values(ascending=False)[:500]
test2
# Out:
# SPEN      3.715597
# ZNF219    2.909842
# MRC1      2.811599
# RORB      2.447682
# TTN       2.327598
#             ...
# ALOX12    0.261297
# DAGLA     0.259268
# SCN1A     0.258925
# NUP107    0.258824
# PLB1      0.258447
# Name: AP0013, Length: 500, dtype: float64

# %%
import panda
test1 = pd.read_table("../Data/GENEPY_JULY21_network_trial_NOD2disease.matrix",
                      index_col== 'Samid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vr/l3nh06095r77bwy94f2wh_jc0000gn/T/ipykernel_22101/2978191577.py in <module>
#       1 test1 = pd.read_table("../Data/GENEPY_JULY21_network_trial_NOD2disease.matrix",
# ----> 2                       index_col== 'Samid')
#
# NameError: name 'index_col' is not defined
